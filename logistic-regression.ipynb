# %% [markdown]
# Pre elaborazione dei dati

# %% [markdown]
# Valuto le prestazioni di Naive Bayes (già applicato) per avere un riferimetno

# %%
nb_model = MultinomialNB()

#alleno il modello
nb_model.fit(X_train_tfidf, y_train)

#previsioni
y_pred_nb = nb_model.predict(X_test_tfidf)

#valuto il modello
print("Accuracy Naive Bayes: {accuracy_score(y_test, u_pred_nb)}")
print(classification_report(y_test, y_pred_nb))
# Out:
# Accuracy Naive Bayes: {accuracy_score(y_test, u_pred_nb)}
#               precision    recall  f1-score   support
#
#           CG       0.80      0.91      0.85      4016
#           OR       0.90      0.77      0.83      4071
#
#     accuracy                           0.84      8087
#    macro avg       0.85      0.84      0.84      8087
# weighted avg       0.85      0.84      0.84      8087

# %% [markdown]
# Implemento la Logistic Regression

# %% [markdown]
# Confronto i risultati

# %% [markdown]
# Miglioramento delle prestazioni tramite ottimizzazione dei parametri

# %% [markdown]
# Stampo altre informazioni utili che sono state trovate con l'applicazione di Logistic Regression
